# %%
from pymongo import MongoClient
import json

# %%
with open('data\\lista_jogadores_chess.json', encoding='utf-8') as json_file:
    json_chess = json.load(json_file)

# %%
json_chess['user']
# Out:
# [{'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/18800602.e26b721f.200x200o.e738019a328a.jpeg',
#   'player_id': 18800602,
#   '@id': 'https://api.chess.com/pub/player/123lt',
#   'url': 'https://www.chess.com/member/123lt',
#   'name': 'Tingjie Lei',
#   'username': '123lt',
#   'title': 'GM',
#   'followers': 36,
#   'country': 'https://api.chess.com/pub/country/CN',
#   'last_online': 1615967972,
#   'joined': 1410059361,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/29499974.39041f89.200x200o.f6478a5ae8e2.jpeg',
#   'player_id': 29499974,
#   '@id': 'https://api.chess.com/pub/player/124chess',
#   'url': 'https://www.chess.com/member/124chess',
#   'name': 'Дмитрий Хегай',
#   'username': '124chess',
#   'title': 'GM',
#   'followers': 87,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'location': 'Красноярск',
#   'last_online': 1616173422,
#   'joined': 1471316272,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/30610578.e05f2196.200x200o.3948baec540a.jpeg',
#   'player_id': 30610578,
#   '@id': 'https://api.chess.com/pub/player/1977ivan',
#   'url': 'https://www.chess.com/member/1977Ivan',
#   'name': 'Ivan Ivanisevic',
#   'username': '1977ivan',
#   'title': 'GM',
#   'followers': 120,
#   'country': 'https://api.chess.com/pub/country/RS',
#   'location': 'Belgrade',
#   'last_online': 1616110240,
#   'joined': 1477565847,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/13013662.cd1d1c55.200x200o.895c29f69c54.jpeg',
#   'player_id': 13013662,
#   '@id': 'https://api.chess.com/pub/player/1stsecond',
#   'url': 'https://www.chess.com/member/1stSecond',
#   'name': 'Nikita Meshkovs',
#   'username': '1stsecond',
#   'title': 'GM',
#   'followers': 716,
#   'country': 'https://api.chess.com/pub/country/LV',
#   'location': 'Riga',
#   'last_online': 1616192647,
#   'joined': 1375617889,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/39230304.414d9817.200x200o.46cbdae3f782.png',
#   'player_id': 39230304,
#   '@id': 'https://api.chess.com/pub/player/2nd_life',
#   'url': 'https://www.chess.com/member/2nd_life',
#   'name': 'Florian Jenni',
#   'username': '2nd_life',
#   'title': 'GM',
#   'followers': 25,
#   'country': 'https://api.chess.com/pub/country/CH',
#   'location': 'Zurich',
#   'last_online': 1615926963,
#   'joined': 1507311109,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/69412324.a8a2af79.200x200o.f77e8743116c.jpeg',
#   'player_id': 69412324,
#   '@id': 'https://api.chess.com/pub/player/4thd-alpeacefulmoon',
#   'url': 'https://www.chess.com/member/4thD-alpeacefulmoon',
#   'name': 'Robert Markus',
#   'username': '4thd-alpeacefulmoon',
#   'title': 'GM',
#   'followers': 2,
#   'country': 'https://api.chess.com/pub/country/RS',
#   'last_online': 1582473834,
#   'joined': 1576488055,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 73365394,
#   '@id': 'https://api.chess.com/pub/player/64aramis64',
#   'url': 'https://www.chess.com/member/64Aramis64',
#   'username': '64aramis64',
#   'title': 'GM',
#   'followers': 9,
#   'country': 'https://api.chess.com/pub/country/US',
#   'last_online': 1615604139,
#   'joined': 1583956667,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 73365768,
#   '@id': 'https://api.chess.com/pub/player/64arthos64',
#   'url': 'https://www.chess.com/member/64Arthos64',
#   'username': '64arthos64',
#   'title': 'GM',
#   'followers': 4,
#   'country': 'https://api.chess.com/pub/country/US',
#   'last_online': 1609891416,
#   'joined': 1583957153,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 73366590,
#   '@id': 'https://api.chess.com/pub/player/64atilla64',
#   'url': 'https://www.chess.com/member/64Atilla64',
#   'username': '64atilla64',
#   'title': 'GM',
#   'followers': 7,
#   'country': 'https://api.chess.com/pub/country/US',
#   'last_online': 1609182946,
#   'joined': 1583958360,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 73366504,
#   '@id': 'https://api.chess.com/pub/player/64dartagnan64',
#   'url': 'https://www.chess.com/member/64Dartagnan64',
#   'username': '64dartagnan64',
#   'title': 'GM',
#   'followers': 17,
#   'country': 'https://api.chess.com/pub/country/US',
#   'last_online': 1615758264,
#   'joined': 1583958242,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 73367192,
#   '@id': 'https://api.chess.com/pub/player/64genghis64',
#   'url': 'https://www.chess.com/member/64Genghis64',
#   'username': '64genghis64',
#   'title': 'GM',
#   'followers': 3,
#   'country': 'https://api.chess.com/pub/country/US',
#   'last_online': 1609620735,
#   'joined': 1583959319,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 73366924,
#   '@id': 'https://api.chess.com/pub/player/64leonidas64',
#   'url': 'https://www.chess.com/member/64Leonidas64',
#   'username': '64leonidas64',
#   'title': 'GM',
#   'followers': 8,
#   'country': 'https://api.chess.com/pub/country/US',
#   'last_online': 1609974579,
#   'joined': 1583958948,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 73366318,
#   '@id': 'https://api.chess.com/pub/player/64porthos64',
#   'url': 'https://www.chess.com/member/64Porthos64',
#   'username': '64porthos64',
#   'title': 'GM',
#   'followers': 7,
#   'country': 'https://api.chess.com/pub/country/US',
#   'last_online': 1587231402,
#   'joined': 1583957977,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 73367098,
#   '@id': 'https://api.chess.com/pub/player/64pyrrhus64',
#   'url': 'https://www.chess.com/member/64Pyrrhus64',
#   'username': '64pyrrhus64',
#   'title': 'GM',
#   'followers': 1,
#   'country': 'https://api.chess.com/pub/country/BI',
#   'last_online': 1609620197,
#   'joined': 1583959191,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 7246509,
#   '@id': 'https://api.chess.com/pub/player/731291',
#   'url': 'https://www.chess.com/member/731291',
#   'name': 'Lance Henderson de La Fuente',
#   'username': '731291',
#   'title': 'GM',
#   'followers': 43,
#   'country': 'https://api.chess.com/pub/country/ES',
#   'last_online': 1615236346,
#   'joined': 1334046062,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/43349734.452f442f.200x200o.7d507c9ece41.jpeg',
#   'player_id': 43349734,
#   '@id': 'https://api.chess.com/pub/player/a-adly',
#   'url': 'https://www.chess.com/member/A-Adly',
#   'name': 'Ahmed Adly',
#   'username': 'a-adly',
#   'title': 'GM',
#   'followers': 403,
#   'country': 'https://api.chess.com/pub/country/EG',
#   'last_online': 1614740265,
#   'joined': 1518647998,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/10968500.f31e4e06.200x200o.2418d3cb8a26.jpeg',
#   'player_id': 10968500,
#   '@id': 'https://api.chess.com/pub/player/a-fier',
#   'url': 'https://www.chess.com/member/A-Fier',
#   'name': 'Alex Fier',
#   'username': 'a-fier',
#   'title': 'GM',
#   'followers': 892,
#   'country': 'https://api.chess.com/pub/country/BR',
#   'location': 'Tbilisi',
#   'last_online': 1616007083,
#   'joined': 1361966117,
#   'status': 'premium',
#   'is_streamer': True,
#   'twitch_url': 'https://twitch.tv/GMAlexFier'},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/59828698.94a02ebe.200x200o.83213b57b80b.jpeg',
#   'player_id': 59828698,
#   '@id': 'https://api.chess.com/pub/player/abasovn',
#   'url': 'https://www.chess.com/member/AbasovN',
#   'name': 'Nijat Abasov',
#   'username': 'abasovn',
#   'title': 'GM',
#   'followers': 112,
#   'country': 'https://api.chess.com/pub/country/AZ',
#   'location': 'Baku',
#   'last_online': 1616095297,
#   'joined': 1555281657,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/17884042.fb9f57ac.200x200o.823a0da5d453.jpeg',
#   'player_id': 17884042,
#   '@id': 'https://api.chess.com/pub/player/abhidabhi',
#   'url': 'https://www.chess.com/member/abhidabhi',
#   'name': 'Abhimanyu Puranik',
#   'username': 'abhidabhi',
#   'title': 'GM',
#   'followers': 477,
#   'country': 'https://api.chess.com/pub/country/IN',
#   'location': 'Pune',
#   'last_online': 1616214181,
#   'joined': 1404098245,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/78571890.c98197e5.200x200o.a777c92a4502.jpeg',
#   'player_id': 78571890,
#   '@id': 'https://api.chess.com/pub/player/abhijeetgupta',
#   'url': 'https://www.chess.com/member/abhijeetgupta',
#   'name': 'Abhijeet Gupta',
#   'username': 'abhijeetgupta',
#   'title': 'GM',
#   'followers': 265,
#   'country': 'https://api.chess.com/pub/country/IN',
#   'last_online': 1615921266,
#   'joined': 1588606684,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/11047160.a434fd29.200x200o.da4781c7e235.jpg',
#   'player_id': 11047160,
#   '@id': 'https://api.chess.com/pub/player/abhijeetgupta1016',
#   'url': 'https://www.chess.com/member/abhijeetgupta1016',
#   'name': 'Abhijeet Gupta',
#   'username': 'abhijeetgupta1016',
#   'title': 'GM',
#   'followers': 1296,
#   'country': 'https://api.chess.com/pub/country/IN',
#   'last_online': 1588598476,
#   'joined': 1362560986,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 90871188,
#   '@id': 'https://api.chess.com/pub/player/abhijeetonyoutube',
#   'url': 'https://www.chess.com/member/Abhijeetonyoutube',
#   'username': 'abhijeetonyoutube',
#   'title': 'GM',
#   'followers': 65,
#   'country': 'https://api.chess.com/pub/country/IN',
#   'last_online': 1613813964,
#   'joined': 1599658917,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/32069494.43d7b2ae.200x200o.d9eb4ec2dc96.jpeg',
#   'player_id': 32069494,
#   '@id': 'https://api.chess.com/pub/player/abhyak',
#   'url': 'https://www.chess.com/member/abhyak',
#   'name': 'Abhijeet Kunte',
#   'username': 'abhyak',
#   'title': 'GM',
#   'followers': 16,
#   'country': 'https://api.chess.com/pub/country/IN',
#   'last_online': 1605751657,
#   'joined': 1483332783,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 17894824,
#   '@id': 'https://api.chess.com/pub/player/abykhovsky',
#   'url': 'https://www.chess.com/member/abykhovsky',
#   'name': 'Anatoly Bykhovsky',
#   'username': 'abykhovsky',
#   'title': 'GM',
#   'followers': 119,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'New York City',
#   'last_online': 1616247953,
#   'joined': 1404174563,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/43428066.330b5a0b.200x200o.1c17ffa0f1e3.jpeg',
#   'player_id': 43428066,
#   '@id': 'https://api.chess.com/pub/player/actorxu',
#   'url': 'https://www.chess.com/member/ActorXu',
#   'name': 'Yi Xu',
#   'username': 'actorxu',
#   'title': 'GM',
#   'followers': 122,
#   'country': 'https://api.chess.com/pub/country/CN',
#   'location': 'Shanghai',
#   'last_online': 1615727298,
#   'joined': 1518859208,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 37277108,
#   '@id': 'https://api.chess.com/pub/player/adaro',
#   'url': 'https://www.chess.com/member/Adaro',
#   'username': 'adaro',
#   'title': 'GM',
#   'followers': 8,
#   'country': 'https://api.chess.com/pub/country/CA',
#   'last_online': 1613229178,
#   'joined': 1500918534,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/34686420.f60146b9.200x200o.ed9325797b69.jpeg',
#   'player_id': 34686420,
#   '@id': 'https://api.chess.com/pub/player/adham_fawzy',
#   'url': 'https://www.chess.com/member/Adham_Fawzy',
#   'name': 'Adham Fawzy',
#   'username': 'adham_fawzy',
#   'title': 'GM',
#   'followers': 1369,
#   'country': 'https://api.chess.com/pub/country/EG',
#   'location': 'Alexandria',
#   'last_online': 1615850700,
#   'joined': 1491891963,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/51280493.809e19c6.200x200o.15504a466b75.png',
#   'player_id': 51280493,
#   '@id': 'https://api.chess.com/pub/player/adiosabu',
#   'url': 'https://www.chess.com/member/adiosabu',
#   'name': 'Alder Escobar',
#   'username': 'adiosabu',
#   'title': 'GM',
#   'followers': 31,
#   'country': 'https://api.chess.com/pub/country/CO',
#   'location': 'Pereira',
#   'last_online': 1615847090,
#   'joined': 1540862913,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/29303436.7f3f2b8b.200x200o.4046d3a60e19.jpeg',
#   'player_id': 29303436,
#   '@id': 'https://api.chess.com/pub/player/afgano29',
#   'url': 'https://www.chess.com/member/afgano29',
#   'name': 'Andres F Gallego',
#   'username': 'afgano29',
#   'title': 'GM',
#   'followers': 209,
#   'country': 'https://api.chess.com/pub/country/CO',
#   'location': 'Medellin',
#   'last_online': 1615187538,
#   'joined': 1470064298,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/11220596.6e662de2.200x200o.e64b53c294de.jpeg',
#   'player_id': 11220596,
#   '@id': 'https://api.chess.com/pub/player/aggy67',
#   'url': 'https://www.chess.com/member/aggy67',
#   'name': 'Simen Agdestein',
#   'username': 'aggy67',
#   'title': 'GM',
#   'followers': 49,
#   'country': 'https://api.chess.com/pub/country/NO',
#   'last_online': 1615973065,
#   'joined': 1363860586,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/4371012.b053d16c.200x200o.ade0e0e838d2.jpeg',
#   'player_id': 4371012,
#   '@id': 'https://api.chess.com/pub/player/agser',
#   'url': 'https://www.chess.com/member/agser',
#   'name': 'Ottomar Ladva',
#   'username': 'agser',
#   'title': 'GM',
#   'followers': 105,
#   'country': 'https://api.chess.com/pub/country/EE',
#   'last_online': 1607482994,
#   'joined': 1292011540,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/18765996.e54ce5a0.200x200o.8b04e8c63ee8.jpeg',
#   'player_id': 18765996,
#   '@id': 'https://api.chess.com/pub/player/airgun1',
#   'url': 'https://www.chess.com/member/airgun1',
#   'name': 'Aaron Summerscale',
#   'username': 'airgun1',
#   'title': 'GM',
#   'followers': 8,
#   'country': 'https://api.chess.com/pub/country/GB',
#   'last_online': 1607710935,
#   'joined': 1409837979,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/8719784.f769006a.200x200o.c45ab07795fe.jpeg',
#   'player_id': 8719784,
#   '@id': 'https://api.chess.com/pub/player/aivanov-ne',
#   'url': 'https://www.chess.com/member/AIvanov-NE',
#   'name': 'Alexander Ivanov',
#   'username': 'aivanov-ne',
#   'title': 'GM',
#   'followers': 0,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'Massachusetts',
#   'last_online': 1509323885,
#   'joined': 1346270785,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/8712604.20bc4cb0.200x200o.6d97b60fdf58.jpeg',
#   'player_id': 8712604,
#   '@id': 'https://api.chess.com/pub/player/akobian-sea',
#   'url': 'https://www.chess.com/member/Akobian-SEA',
#   'name': 'Varuzhan Akobian',
#   'username': 'akobian-sea',
#   'title': 'GM',
#   'followers': 12,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'Washington',
#   'last_online': 1353400995,
#   'joined': 1346218846,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/13239548.4a7619aa.200x200o.bcf68d069975.jpeg',
#   'player_id': 13239548,
#   '@id': 'https://api.chess.com/pub/player/akobian-stl',
#   'url': 'https://www.chess.com/member/Akobian-STL',
#   'name': 'Varuzhan Akobian',
#   'username': 'akobian-stl',
#   'title': 'GM',
#   'followers': 4,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'Missouri',
#   'last_online': 1509321168,
#   'joined': 1377175279,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/12947654.ee7ecf4f.200x200o.3feebee3fb40.jpeg',
#   'player_id': 12947654,
#   '@id': 'https://api.chess.com/pub/player/akshatchandra',
#   'url': 'https://www.chess.com/member/AkshatChandra',
#   'name': 'Akshat Chandra',
#   'username': 'akshatchandra',
#   'title': 'GM',
#   'followers': 149,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'Saint Louis',
#   'last_online': 1524153992,
#   'joined': 1375195437,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/6179690.a3b2c80b.200x200o.c53fee8ba6e8.png',
#   'player_id': 6179690,
#   '@id': 'https://api.chess.com/pub/player/akshayraj_kore',
#   'url': 'https://www.chess.com/member/Akshayraj_Kore',
#   'name': 'Akshayraj Kore',
#   'username': 'akshayraj_kore',
#   'title': 'GM',
#   'followers': 90,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'Ashburn',
#   'last_online': 1616202526,
#   'joined': 1322112601,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 15438952,
#   '@id': 'https://api.chess.com/pub/player/aleksa74',
#   'url': 'https://www.chess.com/member/aleksa74',
#   'username': 'aleksa74',
#   'title': 'GM',
#   'followers': 111,
#   'country': 'https://api.chess.com/pub/country/RS',
#   'last_online': 1616233999,
#   'joined': 1388997295,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/33190437.40740a3b.200x200o.75d3f91b73b8.jpeg',
#   'player_id': 33190437,
#   '@id': 'https://api.chess.com/pub/player/aleksandrovaleksei',
#   'url': 'https://www.chess.com/member/aleksandrovaleksei',
#   'name': 'Aleksei Aleksandrov',
#   'username': 'aleksandrovaleksei',
#   'title': 'GM',
#   'followers': 52,
#   'country': 'https://api.chess.com/pub/country/BY',
#   'last_online': 1616205851,
#   'joined': 1487065930,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 44532158,
#   '@id': 'https://api.chess.com/pub/player/alexander-evdokimov',
#   'url': 'https://www.chess.com/member/alexander-evdokimov',
#   'name': 'Alexander Evdokimov',
#   'username': 'alexander-evdokimov',
#   'title': 'GM',
#   'followers': 19,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'last_online': 1616152419,
#   'joined': 1521726302,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/2534106.a23fc73f.200x200o.9619bd05677b.jpeg',
#   'player_id': 2534106,
#   '@id': 'https://api.chess.com/pub/player/alexanderl',
#   'url': 'https://www.chess.com/member/AlexanderL',
#   'name': 'Aleksandr Lenderman',
#   'username': 'alexanderl',
#   'title': 'GM',
#   'followers': 1436,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'New York City',
#   'last_online': 1616182427,
#   'joined': 1265635556,
#   'status': 'premium',
#   'is_streamer': True,
#   'twitch_url': 'https://twitch.tv/gmlenderman'},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/10322550.a6b5e4ad.200x200o.34f276057c86.jpeg',
#   'player_id': 10322550,
#   '@id': 'https://api.chess.com/pub/player/alexander_donchenko',
#   'url': 'https://www.chess.com/member/Alexander_Donchenko',
#   'name': 'Alexander Donchenko',
#   'username': 'alexander_donchenko',
#   'title': 'GM',
#   'followers': 559,
#   'country': 'https://api.chess.com/pub/country/DE',
#   'last_online': 1616238854,
#   'joined': 1357497907,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/25487812.9eadd0b5.200x200o.8a7c628df6a8.jpeg',
#   'player_id': 25487812,
#   '@id': 'https://api.chess.com/pub/player/alexander_moskalenko',
#   'url': 'https://www.chess.com/member/Alexander_Moskalenko',
#   'name': 'Alexander Moskalenko',
#   'username': 'alexander_moskalenko',
#   'title': 'GM',
#   'followers': 1088,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'location': 'Москва',
#   'last_online': 1616007417,
#   'joined': 1449680458,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/22106804.ef386783.200x200o.397d4aa81ac6.jpeg',
#   'player_id': 22106804,
#   '@id': 'https://api.chess.com/pub/player/alexander_zubov',
#   'url': 'https://www.chess.com/member/Alexander_Zubov',
#   'name': 'Alexander Zubov',
#   'username': 'alexander_zubov',
#   'title': 'GM',
#   'followers': 1436,
#   'country': 'https://api.chess.com/pub/country/UA',
#   'location': "Nikolaev, Mykolayivs'Ka Oblast', Ukraine",
#   'last_online': 1616241136,
#   'joined': 1429883667,
#   'status': 'premium',
#   'is_streamer': True,
#   'twitch_url': 'https://twitch.tv/zubovchess'},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/38748136.14aec2f1.200x200o.1e748deb828f.jpeg',
#   'player_id': 38748136,
#   '@id': 'https://api.chess.com/pub/player/alexandr_predke',
#   'url': 'https://www.chess.com/member/Alexandr_Predke',
#   'name': 'Alexandr Predke',
#   'username': 'alexandr_predke',
#   'title': 'GM',
#   'followers': 23,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'last_online': 1611082531,
#   'joined': 1505754259,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 27008932,
#   '@id': 'https://api.chess.com/pub/player/alexchess1062',
#   'url': 'https://www.chess.com/member/alexchess1062',
#   'username': 'alexchess1062',
#   'title': 'GM',
#   'followers': 47,
#   'country': 'https://api.chess.com/pub/country/US',
#   'last_online': 1614581489,
#   'joined': 1456815851,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/37651132.3c55f120.200x200o.d0af7f496710.jpeg',
#   'player_id': 37651132,
#   '@id': 'https://api.chess.com/pub/player/alexchess1984',
#   'url': 'https://www.chess.com/member/Alexchess1984',
#   'name': 'Alexey Kislinsky',
#   'username': 'alexchess1984',
#   'title': 'GM',
#   'followers': 48,
#   'country': 'https://api.chess.com/pub/country/CZ',
#   'location': 'Киев',
#   'last_online': 1616245830,
#   'joined': 1502186371,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/18153308.999025f4.200x200o.321b6ce3f4a2.jpeg',
#   'player_id': 18153308,
#   '@id': 'https://api.chess.com/pub/player/alexcolovic',
#   'url': 'https://www.chess.com/member/alexcolovic',
#   'name': 'Aleksandar Colovic',
#   'username': 'alexcolovic',
#   'title': 'GM',
#   'followers': 332,
#   'country': 'https://api.chess.com/pub/country/MK',
#   'last_online': 1616100916,
#   'joined': 1405877355,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/4185042.f1d27ec8.200x200o.e0c59b5ccb8b.jpeg',
#   'player_id': 4185042,
#   '@id': 'https://api.chess.com/pub/player/alexeishirov',
#   'url': 'https://www.chess.com/member/AlexeiShirov',
#   'name': 'Alexei Shirov',
#   'username': 'alexeishirov',
#   'title': 'GM',
#   'followers': 315,
#   'country': 'https://api.chess.com/pub/country/ES',
#   'last_online': 1616231195,
#   'joined': 1288416382,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/63565062.0cba2cd4.200x200o.ba7b3c7aedd2.jpeg',
#   'player_id': 63565062,
#   '@id': 'https://api.chess.com/pub/player/alexhuzman',
#   'url': 'https://www.chess.com/member/Alexhuzman',
#   'name': 'Alex Huzman',
#   'username': 'alexhuzman',
#   'title': 'GM',
#   'followers': 6,
#   'country': 'https://api.chess.com/pub/country/IL',
#   'last_online': 1605977358,
#   'joined': 1563861944,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/4268408.4efd9fe8.200x200o.f1562067cf08.jpeg',
#   'player_id': 4268408,
#   '@id': 'https://api.chess.com/pub/player/alexonischuk',
#   'url': 'https://www.chess.com/member/AlexOnischuk',
#   'name': 'Alex Onischuk',
#   'username': 'alexonischuk',
#   'title': 'GM',
#   'followers': 105,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'Texas',
#   'last_online': 1616248867,
#   'joined': 1290046760,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 76468406,
#   '@id': 'https://api.chess.com/pub/player/alexrustemov',
#   'url': 'https://www.chess.com/member/alexrustemov',
#   'name': 'Alexander Rustemov',
#   'username': 'alexrustemov',
#   'title': 'GM',
#   'followers': 26,
#   'country': 'https://api.chess.com/pub/country/BY',
#   'location': 'Minsk',
#   'last_online': 1616225963,
#   'joined': 1586696209,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 84997260,
#   '@id': 'https://api.chess.com/pub/player/alexsur1981',
#   'url': 'https://www.chess.com/member/Alexsur1981',
#   'name': 'Aleksei Pridorozhni',
#   'username': 'alexsur1981',
#   'title': 'GM',
#   'followers': 43,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'last_online': 1616083341,
#   'joined': 1593441443,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/38427992.4ef7921e.200x200o.34a1f01ce75f.jpeg',
#   'player_id': 38427992,
#   '@id': 'https://api.chess.com/pub/player/alexvangog',
#   'url': 'https://www.chess.com/member/AlexVanGog',
#   'name': 'Aleksey Goganov',
#   'username': 'alexvangog',
#   'title': 'GM',
#   'followers': 31,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'location': 'Saint-Petersburg',
#   'last_online': 1614794103,
#   'joined': 1504712343,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/4975207.1459e031.200x200o.382dc5c891a4.jpeg',
#   'player_id': 4975207,
#   '@id': 'https://api.chess.com/pub/player/alexyermo',
#   'url': 'https://www.chess.com/member/AlexYermo',
#   'name': 'Alex Yermolinsky',
#   'username': 'alexyermo',
#   'title': 'GM',
#   'followers': 265,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'Sioux Falls, SD',
#   'last_online': 1616197626,
#   'joined': 1302569448,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/9919120.36cbdcb4.200x200o.fc9d90ed4a19.jpg',
#   'player_id': 9919120,
#   '@id': 'https://api.chess.com/pub/player/alex_goloshchapov',
#   'url': 'https://www.chess.com/member/Alex_Goloshchapov',
#   'name': 'Aleksander Goloshchapov',
#   'username': 'alex_goloshchapov',
#   'title': 'GM',
#   'followers': 25,
#   'country': 'https://api.chess.com/pub/country/UA',
#   'location': 'Kharkov',
#   'last_online': 1616159705,
#   'joined': 1354837366,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/27594810.91fe7f89.200x200o.f818d8d44334.jpeg',
#   'player_id': 27594810,
#   '@id': 'https://api.chess.com/pub/player/alex_stripunsky',
#   'url': 'https://www.chess.com/member/Alex_Stripunsky',
#   'name': 'Alex Stripunsky',
#   'username': 'alex_stripunsky',
#   'title': 'GM',
#   'followers': 69,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'Fair Lawn',
#   'last_online': 1615945320,
#   'joined': 1459803316,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/31585292.731fad08.200x200o.2e48181e0e0a.png',
#   'player_id': 31585292,
#   '@id': 'https://api.chess.com/pub/player/algeriano22',
#   'url': 'https://www.chess.com/member/Algeriano22',
#   'name': 'Haddouche Mohamed',
#   'username': 'algeriano22',
#   'title': 'GM',
#   'followers': 270,
#   'country': 'https://api.chess.com/pub/country/DZ',
#   'location': 'Sidi Bel abbes',
#   'last_online': 1615916101,
#   'joined': 1481619746,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/11301268.241cfbbc.200x200o.9d434e2a00b9.png',
#   'player_id': 11301268,
#   '@id': 'https://api.chess.com/pub/player/allanstig',
#   'url': 'https://www.chess.com/member/AllanStig',
#   'name': 'Allan Stig Rasmussen',
#   'username': 'allanstig',
#   'title': 'GM',
#   'followers': 43,
#   'country': 'https://api.chess.com/pub/country/DK',
#   'location': 'Viborg',
#   'last_online': 1615595869,
#   'joined': 1364422646,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 63192588,
#   '@id': 'https://api.chess.com/pub/player/almo64',
#   'url': 'https://www.chess.com/member/almo64',
#   'name': 'Alexander Motylev',
#   'username': 'almo64',
#   'title': 'GM',
#   'followers': 16,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'last_online': 1615586294,
#   'joined': 1562870370,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/53230370.9c2972a7.200x200o.a1735f7cf5c7.jpeg',
#   'player_id': 53230370,
#   '@id': 'https://api.chess.com/pub/player/alphaodin',
#   'url': 'https://www.chess.com/member/AlphaOdin',
#   'username': 'alphaodin',
#   'title': 'GM',
#   'followers': 140,
#   'country': 'https://api.chess.com/pub/country/XX',
#   'last_online': 1616235263,
#   'joined': 1544788422,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/30494226.3ae10dcd.200x200o.d51eac6bc905.jpeg',
#   'player_id': 30494226,
#   '@id': 'https://api.chess.com/pub/player/amintabatabaei',
#   'url': 'https://www.chess.com/member/amintabatabaei',
#   'name': 'Amin Tabatabaei',
#   'username': 'amintabatabaei',
#   'title': 'GM',
#   'followers': 834,
#   'country': 'https://api.chess.com/pub/country/IR',
#   'last_online': 1616008857,
#   'joined': 1476970017,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/76729100.7f404370.200x200o.a054a4db5322.jpeg',
#   'player_id': 76729100,
#   '@id': 'https://api.chess.com/pub/player/amirbagheri78',
#   'url': 'https://www.chess.com/member/AmirBagheri78',
#   'name': 'Amir Bagheri',
#   'username': 'amirbagheri78',
#   'title': 'GM',
#   'followers': 36,
#   'country': 'https://api.chess.com/pub/country/FR',
#   'location': 'Nice',
#   'last_online': 1616173095,
#   'joined': 1586906458,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/20739392.88f2cbec.200x200o.bb0370e70ccc.jpeg',
#   'player_id': 20739392,
#   '@id': 'https://api.chess.com/pub/player/amirreza_p',
#   'url': 'https://www.chess.com/member/Amirreza_p',
#   'name': 'amirreza pourramezanali',
#   'username': 'amirreza_p',
#   'title': 'GM',
#   'followers': 410,
#   'country': 'https://api.chess.com/pub/country/IR',
#   'location': 'Rasht',
#   'last_online': 1616241883,
#   'joined': 1421914729,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/22446876.db005648.200x200o.e4229ddcb46b.jpeg',
#   'player_id': 22446876,
#   '@id': 'https://api.chess.com/pub/player/anaconda1983',
#   'url': 'https://www.chess.com/member/Anaconda1983',
#   'name': 'Gergely-Andras-Gyula Szabo',
#   'username': 'anaconda1983',
#   'title': 'GM',
#   'followers': 69,
#   'country': 'https://api.chess.com/pub/country/RO',
#   'location': 'Brasov',
#   'last_online': 1615132338,
#   'joined': 1431985843,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/8441420.988dc369.200x200o.5e63e8b0a9fa.jpeg',
#   'player_id': 8441420,
#   '@id': 'https://api.chess.com/pub/player/anand',
#   'url': 'https://www.chess.com/member/Anand',
#   'name': 'Viswanathan Anand',
#   'username': 'anand',
#   'title': 'GM',
#   'followers': 2469,
#   'country': 'https://api.chess.com/pub/country/IN',
#   'last_online': 1373826927,
#   'joined': 1344162603,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/60172144.4865d2e6.200x200o.7e947422e0d3.jpeg',
#   'player_id': 60172144,
#   '@id': 'https://api.chess.com/pub/player/andabata',
#   'url': 'https://www.chess.com/member/andabata',
#   'username': 'andabata',
#   'title': 'GM',
#   'followers': 91,
#   'country': 'https://api.chess.com/pub/country/US',
#   'last_online': 1614735591,
#   'joined': 1556070758,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 27856580,
#   '@id': 'https://api.chess.com/pub/player/andrbaryshpolets',
#   'url': 'https://www.chess.com/member/AndrBaryshpolets',
#   'name': 'Andrey Baryshpolets',
#   'username': 'andrbaryshpolets',
#   'title': 'GM',
#   'followers': 156,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'Lubbock',
#   'last_online': 1615913424,
#   'joined': 1461304494,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/10767030.e0825f66.200x200o.7e9a1d92598d.jpeg',
#   'player_id': 10767030,
#   '@id': 'https://api.chess.com/pub/player/andreikka',
#   'url': 'https://www.chess.com/member/Andreikka',
#   'name': 'Andrey Esipenko',
#   'username': 'andreikka',
#   'title': 'GM',
#   'followers': 2579,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'last_online': 1616235996,
#   'joined': 1360502176,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 57173942,
#   '@id': 'https://api.chess.com/pub/player/andrei_belozerov',
#   'url': 'https://www.chess.com/member/Andrei_Belozerov',
#   'name': 'Andrei Belozerov',
#   'username': 'andrei_belozerov',
#   'title': 'GM',
#   'followers': 308,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'location': 'Tomsk',
#   'last_online': 1616251476,
#   'joined': 1549777389,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/19271242.b7c4d596.200x200o.37611f6ca237.jpeg',
#   'player_id': 19271242,
#   '@id': 'https://api.chess.com/pub/player/andrejs_sokolov',
#   'url': 'https://www.chess.com/member/Andrejs_Sokolov',
#   'name': 'Andrejs Sokolovs',
#   'username': 'andrejs_sokolov',
#   'title': 'GM',
#   'followers': 29,
#   'country': 'https://api.chess.com/pub/country/LV',
#   'last_online': 1611684166,
#   'joined': 1413104214,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/28000608.3ad0a317.200x200o.b7f86a5e771a.jpeg',
#   'player_id': 28000608,
#   '@id': 'https://api.chess.com/pub/player/andreystukopin',
#   'url': 'https://www.chess.com/member/andreystukopin',
#   'name': 'Andrey Stukopin',
#   'username': 'andreystukopin',
#   'title': 'GM',
#   'followers': 359,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'Austin',
#   'last_online': 1616243392,
#   'joined': 1462126955,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/24471856.edb6a6b8.200x200o.e901c6e472bd.jpeg',
#   'player_id': 24471856,
#   '@id': 'https://api.chess.com/pub/player/andyrodri',
#   'url': 'https://www.chess.com/member/andyrodri',
#   'name': 'Andres Rodriguez Vila',
#   'username': 'andyrodri',
#   'title': 'GM',
#   'followers': 63,
#   'country': 'https://api.chess.com/pub/country/AR',
#   'location': 'Buenos Aires',
#   'last_online': 1614790262,
#   'joined': 1444259841,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 37642898,
#   '@id': 'https://api.chess.com/pub/player/angelogm',
#   'url': 'https://www.chess.com/member/AngeloGM',
#   'username': 'angelogm',
#   'title': 'GM',
#   'followers': 33,
#   'country': 'https://api.chess.com/pub/country/PE',
#   'last_online': 1615662933,
#   'joined': 1502152679,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/22252178.d8dff8c3.200x200o.8375b4cb1335.jpeg',
#   'player_id': 22252178,
#   '@id': 'https://api.chess.com/pub/player/anishgiri',
#   'url': 'https://www.chess.com/member/AnishGiri',
#   'name': 'Anish Giri',
#   'username': 'anishgiri',
#   'title': 'GM',
#   'followers': 5073,
#   'country': 'https://api.chess.com/pub/country/NL',
#   'location': 'The Hague',
#   'last_online': 1615973284,
#   'joined': 1430772657,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/85851574.8bbe59b0.200x200o.c7390399d0ed.jpeg',
#   'player_id': 85851574,
#   '@id': 'https://api.chess.com/pub/player/anishonyoutube',
#   'url': 'https://www.chess.com/member/AnishOnYoutube',
#   'name': 'Anish Giri',
#   'username': 'anishonyoutube',
#   'title': 'GM',
#   'followers': 5823,
#   'country': 'https://api.chess.com/pub/country/NL',
#   'location': 'The Hague',
#   'last_online': 1609271733,
#   'joined': 1593987775,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/13239452.33a77059.200x200o.e1556c6b3d12.jpeg',
#   'player_id': 13239452,
#   '@id': 'https://api.chess.com/pub/player/anka-sea',
#   'url': 'https://www.chess.com/member/Anka-SEA',
#   'name': 'Emil Anka',
#   'username': 'anka-sea',
#   'title': 'GM',
#   'followers': 0,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'Washington',
#   'last_online': 1509321468,
#   'joined': 1377174772,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/28651376.c2ab7264.200x200o.c090debc3c0e.jpeg',
#   'player_id': 28651376,
#   '@id': 'https://api.chess.com/pub/player/annawel',
#   'url': 'https://www.chess.com/member/Annawel',
#   'name': 'Jules Moussard',
#   'username': 'annawel',
#   'title': 'GM',
#   'followers': 641,
#   'country': 'https://api.chess.com/pub/country/FR',
#   'last_online': 1615320563,
#   'joined': 1466038494,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/76187764.891906e8.200x200o.5f7ea32114ad.jpeg',
#   'player_id': 76187764,
#   '@id': 'https://api.chess.com/pub/player/anna_muzychuk',
#   'url': 'https://www.chess.com/member/Anna_Muzychuk',
#   'name': 'Anna Muzychuk',
#   'username': 'anna_muzychuk',
#   'title': 'GM',
#   'followers': 559,
#   'country': 'https://api.chess.com/pub/country/UA',
#   'location': 'Lviv',
#   'last_online': 1616236239,
#   'joined': 1586461173,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/18206892.d4130b22.200x200o.50da65940490.jpeg',
#   'player_id': 18206892,
#   '@id': 'https://api.chess.com/pub/player/anthonywirig',
#   'url': 'https://www.chess.com/member/AnthonyWirig',
#   'name': 'Anthony Wirig',
#   'username': 'anthonywirig',
#   'title': 'GM',
#   'followers': 264,
#   'country': 'https://api.chess.com/pub/country/FR',
#   'last_online': 1616229223,
#   'joined': 1406214208,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/28435214.6de7dd6c.200x200o.7687f7b89e34.jpeg',
#   'player_id': 28435214,
#   '@id': 'https://api.chess.com/pub/player/antipov_mikhail_al',
#   'url': 'https://www.chess.com/member/Antipov_Mikhail_Al',
#   'name': 'Mikhail Antipov',
#   'username': 'antipov_mikhail_al',
#   'title': 'GM',
#   'followers': 117,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'location': 'Moscow',
#   'last_online': 1616197833,
#   'joined': 1464709202,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/24181460.b5143d82.200x200o.98c516f717c7.jpeg',
#   'player_id': 24181460,
#   '@id': 'https://api.chess.com/pub/player/antonshomoev',
#   'url': 'https://www.chess.com/member/AntonShomoev',
#   'name': 'Anton Shomoev',
#   'username': 'antonshomoev',
#   'title': 'GM',
#   'followers': 18,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'location': '1',
#   'last_online': 1616229893,
#   'joined': 1442646167,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/17534752.eadf1d19.200x200o.3b0e1d95735a.jpeg',
#   'player_id': 17534752,
#   '@id': 'https://api.chess.com/pub/player/antonsmirnov',
#   'url': 'https://www.chess.com/member/AntonSmirnov',
#   'name': 'Anton Smirnov',
#   'username': 'antonsmirnov',
#   'title': 'GM',
#   'followers': 1141,
#   'country': 'https://api.chess.com/pub/country/AU',
#   'location': 'Sydney',
#   'last_online': 1616216750,
#   'joined': 1401705438,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/17050352.124fbca8.200x200o.2a6c4ca147bb.jpeg',
#   'player_id': 17050352,
#   '@id': 'https://api.chess.com/pub/player/anton_demchenko',
#   'url': 'https://www.chess.com/member/Anton_Demchenko',
#   'name': 'Anton Demchenko',
#   'username': 'anton_demchenko',
#   'title': 'GM',
#   'followers': 1340,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'location': 'Novorossiysk',
#   'last_online': 1616244485,
#   'joined': 1398437024,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/34186988.7aee3b02.200x200o.7a9f28a475fd.jpeg',
#   'player_id': 34186988,
#   '@id': 'https://api.chess.com/pub/player/anuar_is',
#   'url': 'https://www.chess.com/member/Anuar_Is',
#   'name': 'Anuar Ismagambetov',
#   'username': 'anuar_is',
#   'title': 'GM',
#   'followers': 325,
#   'country': 'https://api.chess.com/pub/country/KZ',
#   'location': 'Astana',
#   'last_online': 1615736572,
#   'joined': 1490252150,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/45931434.bf77e62e.200x200o.447cdc212ff3.jpeg',
#   'player_id': 45931434,
#   '@id': 'https://api.chess.com/pub/player/anurag328',
#   'url': 'https://www.chess.com/member/Anurag328',
#   'name': 'Anurag Mhamal',
#   'username': 'anurag328',
#   'title': 'GM',
#   'followers': 160,
#   'country': 'https://api.chess.com/pub/country/IN',
#   'location': 'Goa, India',
#   'last_online': 1616182043,
#   'joined': 1525566064,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/27168196.4c1ff3d9.200x200o.e7f139ecd010.jpeg',
#   'player_id': 27168196,
#   '@id': 'https://api.chess.com/pub/player/arabicfalcon',
#   'url': 'https://www.chess.com/member/Arabicfalcon',
#   'name': 'Salem AR Saleh',
#   'username': 'arabicfalcon',
#   'title': 'GM',
#   'followers': 1683,
#   'country': 'https://api.chess.com/pub/country/AE',
#   'location': 'Sharjah',
#   'last_online': 1616183916,
#   'joined': 1457640860,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 35698852,
#   '@id': 'https://api.chess.com/pub/player/aradej',
#   'url': 'https://www.chess.com/member/Aradej',
#   'name': 'Dejan Pikula',
#   'username': 'aradej',
#   'title': 'GM',
#   'followers': 21,
#   'country': 'https://api.chess.com/pub/country/RS',
#   'last_online': 1615403214,
#   'joined': 1495371383,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/61042862.4c0b5c2d.200x200o.d7a5d644e6d6.jpeg',
#   'player_id': 61042862,
#   '@id': 'https://api.chess.com/pub/player/arambai',
#   'url': 'https://www.chess.com/member/Arambai',
#   'username': 'arambai',
#   'title': 'GM',
#   'followers': 60,
#   'country': 'https://api.chess.com/pub/country/TH',
#   'last_online': 1615276063,
#   'joined': 1557979483,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/55505950.55ff0961.200x200o.1667761000b2.png',
#   'player_id': 55505950,
#   '@id': 'https://api.chess.com/pub/player/aravindhchess1999',
#   'url': 'https://www.chess.com/member/Aravindhchess1999',
#   'name': 'Aravindh Chithambaram',
#   'username': 'aravindhchess1999',
#   'title': 'GM',
#   'followers': 519,
#   'country': 'https://api.chess.com/pub/country/IN',
#   'last_online': 1616177328,
#   'joined': 1546598831,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/56757462.5b6b3796.200x200o.07d6b3356c88.jpeg',
#   'player_id': 56757462,
#   '@id': 'https://api.chess.com/pub/player/arcymisie',
#   'url': 'https://www.chess.com/member/Arcymisie',
#   'name': 'Akademia Szachowa',
#   'username': 'arcymisie',
#   'title': 'GM',
#   'followers': 32,
#   'country': 'https://api.chess.com/pub/country/PL',
#   'last_online': 1616236055,
#   'joined': 1548932091,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/16973574.1cdbaf9f.200x200o.db1e072ffc6e.jpeg',
#   'player_id': 16973574,
#   '@id': 'https://api.chess.com/pub/player/arencibia',
#   'url': 'https://www.chess.com/member/Arencibia',
#   'name': 'Walter Arencibia',
#   'username': 'arencibia',
#   'title': 'GM',
#   'followers': 191,
#   'country': 'https://api.chess.com/pub/country/CU',
#   'location': 'Sharjah',
#   'last_online': 1616241978,
#   'joined': 1397933119,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 75466500,
#   '@id': 'https://api.chess.com/pub/player/argyllprince',
#   'url': 'https://www.chess.com/member/ArgyllPrince',
#   'username': 'argyllprince',
#   'title': 'GM',
#   'followers': 1,
#   'country': 'https://api.chess.com/pub/country/VG',
#   'last_online': 1594044270,
#   'joined': 1585867561,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/78416266.4a662a55.200x200o.20d22992a860.jpeg',
#   'player_id': 78416266,
#   '@id': 'https://api.chess.com/pub/player/ariancito1',
#   'url': 'https://www.chess.com/member/Ariancito1',
#   'name': 'Arian González Pérez',
#   'username': 'ariancito1',
#   'title': 'GM',
#   'followers': 6,
#   'country': 'https://api.chess.com/pub/country/CU',
#   'location': 'España',
#   'last_online': 1613237802,
#   'joined': 1588444322,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/67456812.c71d3199.200x200o.2e86d41eec4d.jpeg',
#   'player_id': 67456812,
#   '@id': 'https://api.chess.com/pub/player/arjunerigaisi2003',
#   'url': 'https://www.chess.com/member/ArjunErigaisi2003',
#   'name': 'Arjun Erigaisi',
#   'username': 'arjunerigaisi2003',
#   'title': 'GM',
#   'followers': 466,
#   'country': 'https://api.chess.com/pub/country/IN',
#   'location': 'Warangal',
#   'last_online': 1614735901,
#   'joined': 1572718642,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/20669298.b546961e.200x200o.b99042cbf56e.jpeg',
#   'player_id': 20669298,
#   '@id': 'https://api.chess.com/pub/player/arkonada50',
#   'url': 'https://www.chess.com/member/arkonada50',
#   'name': 'Arkadij Rotstein',
#   'username': 'arkonada50',
#   'title': 'GM',
#   'followers': 0,
#   'country': 'https://api.chess.com/pub/country/DE',
#   'location': 'Köln',
#   'last_online': 1615633413,
#   'joined': 1421496287,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/32114346.ad0f8a65.200x200o.f58767252944.jpeg',
#   'player_id': 32114346,
#   '@id': 'https://api.chess.com/pub/player/arm-akiba',
#   'url': 'https://www.chess.com/member/Arm-Akiba',
#   'name': 'Gabriel Sargissian',
#   'username': 'arm-akiba',
#   'title': 'GM',
#   'followers': 271,
#   'country': 'https://api.chess.com/pub/country/AM',
#   'last_online': 1615138526,
#   'joined': 1483475111,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 85950206,
#   '@id': 'https://api.chess.com/pub/player/armenianlion',
#   'url': 'https://www.chess.com/member/ArmenianLion',
#   'name': 'Levon Aronian',
#   'username': 'armenianlion',
#   'title': 'GM',
#   'followers': 63,
#   'country': 'https://api.chess.com/pub/country/AM',
#   'last_online': 1599334494,
#   'joined': 1594058344,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/5979666.495de01c.200x200o.04be942e17de.jpeg',
#   'player_id': 5979666,
#   '@id': 'https://api.chess.com/pub/player/arnaudovp',
#   'url': 'https://www.chess.com/member/ArnaudovP',
#   'name': 'Petar G. Arnaudov',
#   'username': 'arnaudovp',
#   'title': 'GM',
#   'followers': 662,
#   'country': 'https://api.chess.com/pub/country/BG',
#   'location': 'Plovdiv',
#   'last_online': 1616145472,
#   'joined': 1319035690,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/34432694.149253ed.200x200o.1340aee2dba2.jpeg',
#   'player_id': 34432694,
#   '@id': 'https://api.chess.com/pub/player/arseniy_nesterov',
#   'url': 'https://www.chess.com/member/Arseniy_Nesterov',
#   'name': 'Arseniy Nesterov',
#   'username': 'arseniy_nesterov',
#   'title': 'GM',
#   'followers': 191,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'location': 'Великий Новгород',
#   'last_online': 1616250579,
#   'joined': 1491036496,
#   'status': 'premium',
#   'is_streamer': True},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/43053602.524d0c7c.200x200o.2e4d6c580932.jpeg',
#   'player_id': 43053602,
#   '@id': 'https://api.chess.com/pub/player/artem_ilyin',
#   'url': 'https://www.chess.com/member/Artem_Ilyin',
#   'name': 'Artem Iljin',
#   'username': 'artem_ilyin',
# ...
#   'url': 'https://www.chess.com/member/oskychess',
#   'name': 'Oscar de la Riva',
#   'username': 'oskychess',
#   'title': 'GM',
#   'followers': 81,
#   'country': 'https://api.chess.com/pub/country/AD',
#   'last_online': 1616181641,
#   'joined': 1490636949,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/4199015.7108a71e.200x200o.15d190b71491.jpeg',
#   'player_id': 4199015,
#   '@id': 'https://api.chess.com/pub/player/oursemare',
#   'url': 'https://www.chess.com/member/oursemare',
#   'name': 'Gilles Miralles',
#   'username': 'oursemare',
#   'title': 'GM',
#   'followers': 265,
#   'country': 'https://api.chess.com/pub/country/FR',
#   'last_online': 1616085356,
#   'joined': 1288708935,
#   'status': 'premium',
#   'is_streamer': True},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/50736166.1956b4d9.200x200o.7f2b05ce5668.jpeg',
#   'player_id': 50736166,
#   '@id': 'https://api.chess.com/pub/player/pablolafuente',
#   'url': 'https://www.chess.com/member/PabloLafuente',
#   'username': 'pablolafuente',
#   'title': 'GM',
#   'followers': 152,
#   'country': 'https://api.chess.com/pub/country/AR',
#   'location': 'Europe',
#   'last_online': 1615719696,
#   'joined': 1539507558,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 65029054,
#   '@id': 'https://api.chess.com/pub/player/pabloricardi',
#   'url': 'https://www.chess.com/member/PabloRicardi',
#   'username': 'pabloricardi',
#   'title': 'GM',
#   'followers': 83,
#   'country': 'https://api.chess.com/pub/country/AR',
#   'last_online': 1608636878,
#   'joined': 1567444586,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/27730422.ee754eb4.200x200o.9bbda721b41a.jpeg',
#   'player_id': 27730422,
#   '@id': 'https://api.chess.com/pub/player/pablozarnicki',
#   'url': 'https://www.chess.com/member/PabloZarnicki',
#   'name': 'Pablo Zarnicki',
#   'username': 'pablozarnicki',
#   'title': 'GM',
#   'followers': 142,
#   'country': 'https://api.chess.com/pub/country/AR',
#   'location': 'Buenos Aires',
#   'last_online': 1616213839,
#   'joined': 1460575192,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/56820970.3235155f.200x200o.10756f5c7198.png',
#   'player_id': 56820970,
#   '@id': 'https://api.chess.com/pub/player/padenie_zvezd',
#   'url': 'https://www.chess.com/member/Padenie_Zvezd',
#   'name': 'Stanislav Bogdanovich',
#   'username': 'padenie_zvezd',
#   'title': 'GM',
#   'followers': 27,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'last_online': 1583111005,
#   'joined': 1549050410,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/32903570.58610540.200x200o.b673915ca9a6.gif',
#   'player_id': 32903570,
#   '@id': 'https://api.chess.com/pub/player/panevezys',
#   'url': 'https://www.chess.com/member/Panevezys',
#   'username': 'panevezys',
#   'title': 'GM',
#   'followers': 4,
#   'country': 'https://api.chess.com/pub/country/LT',
#   'location': 'Panevezys',
#   'last_online': 1602495023,
#   'joined': 1486154171,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 80152938,
#   '@id': 'https://api.chess.com/pub/player/papullon',
#   'url': 'https://www.chess.com/member/Papullon',
#   'username': 'papullon',
#   'title': 'GM',
#   'followers': 19,
#   'country': 'https://api.chess.com/pub/country/SE',
#   'last_online': 1615028104,
#   'joined': 1590093824,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/25339094.3777ef22.200x200o.15e42b8ba15f.jpeg',
#   'player_id': 25339094,
#   '@id': 'https://api.chess.com/pub/player/paralinch',
#   'url': 'https://www.chess.com/member/Paralinch',
#   'name': 'Daniil Lintchevski',
#   'username': 'paralinch',
#   'title': 'GM',
#   'followers': 115,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'location': 'Санкт-Петербург',
#   'last_online': 1616076491,
#   'joined': 1448901777,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/32230490.a56aa9ad.200x200o.f83a51f22737.jpeg',
#   'player_id': 32230490,
#   '@id': 'https://api.chess.com/pub/player/parhamov',
#   'url': 'https://www.chess.com/member/Parhamov',
#   'name': 'Parham Maghsoodloo',
#   'username': 'parhamov',
#   'title': 'GM',
#   'followers': 4479,
#   'country': 'https://api.chess.com/pub/country/IR',
#   'location': 'Gorgan',
#   'last_online': 1616216286,
#   'joined': 1483868974,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/8963150.2223e9d0.200x200o.c848100878e6.jpeg',
#   'player_id': 8963150,
#   '@id': 'https://api.chess.com/pub/player/parimarjan',
#   'url': 'https://www.chess.com/member/Parimarjan',
#   'name': 'Parimarjan Negi',
#   'username': 'parimarjan',
#   'title': 'GM',
#   'followers': 94,
#   'country': 'https://api.chess.com/pub/country/IN',
#   'location': 'New Delhi',
#   'last_online': 1605025970,
#   'joined': 1348071374,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 6615822,
#   '@id': 'https://api.chess.com/pub/player/parsifal7',
#   'url': 'https://www.chess.com/member/Parsifal7',
#   'name': 'harold james plaskett',
#   'username': 'parsifal7',
#   'title': 'GM',
#   'followers': 1,
#   'country': 'https://api.chess.com/pub/country/ES',
#   'location': 'cartagena',
#   'last_online': 1332529486,
#   'joined': 1328384053,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/27880414.e9dc3e7c.200x200o.e69b6b5b751d.jpeg',
#   'player_id': 27880414,
#   '@id': 'https://api.chess.com/pub/player/paul66666',
#   'url': 'https://www.chess.com/member/Paul66666',
#   'name': 'Meelis Kanep',
#   'username': 'paul66666',
#   'title': 'GM',
#   'followers': 47,
#   'country': 'https://api.chess.com/pub/country/EE',
#   'last_online': 1615770276,
#   'joined': 1461438296,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/21423008.5e578422.200x200o.37a871c0f291.jpeg',
#   'player_id': 21423008,
#   '@id': 'https://api.chess.com/pub/player/paulfromspb',
#   'url': 'https://www.chess.com/member/PaulfromSPb',
#   'name': 'Pavel Anisimov',
#   'username': 'paulfromspb',
#   'title': 'GM',
#   'followers': 170,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'location': 'Saint-P',
#   'last_online': 1616187227,
#   'joined': 1425800547,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/29348400.a5e28839.200x200o.5d0b968566fa.jpeg',
#   'player_id': 29348400,
#   '@id': 'https://api.chess.com/pub/player/paulphoenix87',
#   'url': 'https://www.chess.com/member/PaulPhoenix87',
#   'name': 'Paul Phoenix',
#   'username': 'paulphoenix87',
#   'title': 'GM',
#   'followers': 40,
#   'country': 'https://api.chess.com/pub/country/CH',
#   'last_online': 1530825215,
#   'joined': 1470351993,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/21929836.4764f3d5.200x200o.c6b618360e59.jpeg',
#   'player_id': 21929836,
#   '@id': 'https://api.chess.com/pub/player/paulvelten',
#   'url': 'https://www.chess.com/member/PaulVelten',
#   'name': 'Paul Velten',
#   'username': 'paulvelten',
#   'title': 'GM',
#   'followers': 83,
#   'country': 'https://api.chess.com/pub/country/FR',
#   'last_online': 1615456392,
#   'joined': 1428788238,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/29817596.0cb58ec3.200x200o.1bfba641a6e5.jpeg',
#   'player_id': 29817596,
#   '@id': 'https://api.chess.com/pub/player/pavelmaletin',
#   'url': 'https://www.chess.com/member/pavelmaletin',
#   'name': 'Pavel Maletin',
#   'username': 'pavelmaletin',
#   'title': 'GM',
#   'followers': 107,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'location': 'Новосибирск',
#   'last_online': 1615620021,
#   'joined': 1473216441,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/36878330.b873f9dc.200x200o.890e6742277a.jpeg',
#   'player_id': 36878330,
#   '@id': 'https://api.chess.com/pub/player/pavel_skatchkov',
#   'url': 'https://www.chess.com/member/pavel_skatchkov',
#   'name': 'Pavel Skatchkov',
#   'username': 'pavel_skatchkov',
#   'title': 'GM',
#   'followers': 10,
#   'country': 'https://api.chess.com/pub/country/RU',
#   'last_online': 1616233076,
#   'joined': 1499508290,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/4302026.76bcfca0.200x200o.99bfe938f748.jpeg',
#   'player_id': 4302026,
#   '@id': 'https://api.chess.com/pub/player/pawelczarnota',
#   'url': 'https://www.chess.com/member/PawelCzarnota',
#   'name': 'Pawel Czarnota',
#   'username': 'pawelczarnota',
#   'title': 'GM',
#   'followers': 857,
#   'country': 'https://api.chess.com/pub/country/PL',
#   'location': 'Olkusz',
#   'last_online': 1616240661,
#   'joined': 1290688923,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/8344034.90d12ae9.200x200o.7879b6fd9111.jpeg',
#   'player_id': 8344034,
#   '@id': 'https://api.chess.com/pub/player/penguingm1',
#   'url': 'https://www.chess.com/member/penguingm1',
#   'name': 'Andrew Tang',
#   'username': 'penguingm1',
#   'title': 'GM',
#   'followers': 6727,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'Princeton, NJ',
#   'last_online': 1616220007,
#   'joined': 1343425021,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/8719382.da1f7533.200x200o.58cf5bddae31.jpeg',
#   'player_id': 8719382,
#   '@id': 'https://api.chess.com/pub/player/perelshteyn-bos',
#   'url': 'https://www.chess.com/member/Perelshteyn-BOS',
#   'name': 'Eugene Perelshteyn',
#   'username': 'perelshteyn-bos',
#   'title': 'GM',
#   'followers': 6,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'Massachusetts',
#   'last_online': 1538070707,
#   'joined': 1346268697,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/25805194.585ab911.200x200o.fc7e6aeac9cd.jpeg',
#   'player_id': 25805194,
#   '@id': 'https://api.chess.com/pub/player/peretyatko',
#   'url': 'https://www.chess.com/member/Peretyatko',
#   'name': 'Gennady Matjushin',
#   'username': 'peretyatko',
#   'title': 'GM',
#   'followers': 26,
#   'country': 'https://api.chess.com/pub/country/UA',
#   'last_online': 1610280019,
#   'joined': 1451270066,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/25714199.5c0cd6c4.200x200o.09c14d3ac6f9.gif',
#   'player_id': 25714199,
#   '@id': 'https://api.chess.com/pub/player/petardrenchev',
#   'url': 'https://www.chess.com/member/petardrenchev',
#   'name': 'Petar Drenchev',
#   'username': 'petardrenchev',
#   'title': 'GM',
#   'followers': 7,
#   'country': 'https://api.chess.com/pub/country/BG',
#   'last_online': 1466436570,
#   'joined': 1450854620,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 77090164,
#   '@id': 'https://api.chess.com/pub/player/peterheinenielsen',
#   'url': 'https://www.chess.com/member/PeterHeineNielsen',
#   'username': 'peterheinenielsen',
#   'title': 'GM',
#   'followers': 2,
#   'country': 'https://api.chess.com/pub/country/LT',
#   'last_online': 1604679512,
#   'joined': 1587218256,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/58960276.1a10be19.200x200o.785e288ffbaa.jpeg',
#   'player_id': 58960276,
#   '@id': 'https://api.chess.com/pub/player/petrkostenko',
#   'url': 'https://www.chess.com/member/petrkostenko',
#   'name': 'Petr Kostenko',
#   'username': 'petrkostenko',
#   'title': 'GM',
#   'followers': 12,
#   'country': 'https://api.chess.com/pub/country/KZ',
#   'last_online': 1613570748,
#   'joined': 1553487847,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/76671914.bece84f7.200x200o.32f6eeed23ea.jpeg',
#   'player_id': 76671914,
#   '@id': 'https://api.chess.com/pub/player/petrvelicka',
#   'url': 'https://www.chess.com/member/PetrVelicka',
#   'name': 'Petr Velicka',
#   'username': 'petrvelicka',
#   'title': 'GM',
#   'followers': 7,
#   'country': 'https://api.chess.com/pub/country/CZ',
#   'location': 'Náměšť nad Oslavou',
#   'last_online': 1611790868,
#   'joined': 1586867331,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 40763230,
#   '@id': 'https://api.chess.com/pub/player/pgw-in-sf',
#   'url': 'https://www.chess.com/member/PGW-in-SF',
#   'name': 'Patrick Wolff',
#   'username': 'pgw-in-sf',
#   'title': 'GM',
#   'followers': 3,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'San Francisco',
#   'last_online': 1598031546,
#   'joined': 1511741425,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/13928556.447a9e23.200x200o.d64edb5765ce.jpeg',
#   'player_id': 13928556,
#   '@id': 'https://api.chess.com/pub/player/phoenix',
#   'url': 'https://www.chess.com/member/Phoenix',
#   'username': 'phoenix',
#   'title': 'GM',
#   'followers': 131,
#   'country': 'https://api.chess.com/pub/country/US',
#   'location': 'Vancouver',
#   'last_online': 1419371970,
#   'joined': 1381950238,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 39984136,
#   '@id': 'https://api.chess.com/pub/player/piacramling',
#   'url': 'https://www.chess.com/member/Piacramling',
#   'name': 'Pia Cramling',
#   'username': 'piacramling',
#   'title': 'GM',
#   'followers': 72,
#   'country': 'https://api.chess.com/pub/country/SE',
#   'location': 'Stockholm',
#   'last_online': 1616063998,
#   'joined': 1509616984,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/30593612.c07bf615.200x200o.256254f24103.jpeg',
#   'player_id': 30593612,
#   '@id': 'https://api.chess.com/pub/player/pidzsy',
#   'url': 'https://www.chess.com/member/Pidzsy',
#   'name': 'Gabor Papp',
#   'username': 'pidzsy',
#   'title': 'GM',
#   'followers': 29,
#   'country': 'https://api.chess.com/pub/country/HU',
#   'location': 'Budapest',
#   'last_online': 1616069634,
#   'joined': 1477476082,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 76303878,
#   '@id': 'https://api.chess.com/pub/player/pittiplatsh',
#   'url': 'https://www.chess.com/member/Pittiplatsh',
#   'name': 'Alexander Naumann',
#   'username': 'pittiplatsh',
#   'title': 'GM',
#   'followers': 0,
#   'country': 'https://api.chess.com/pub/country/DE',
#   'last_online': 1614115033,
#   'joined': 1586552911,
#   'status': 'premium',
#   'is_streamer': False},
#  {'player_id': 77090224,
#   '@id': 'https://api.chess.com/pub/player/pkclub',
#   'url': 'https://www.chess.com/member/PKCLUB',
#   'name': 'Xue Zhao',
#   'username': 'pkclub',
#   'title': 'GM',
#   'followers': 23,
#   'country': 'https://api.chess.com/pub/country/CN',
#   'last_online': 1616240223,
#   'joined': 1587218310,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/22639240.0523b4f7.200x200o.6e4a5beae996.jpeg',
#   'player_id': 22639240,
#   '@id': 'https://api.chess.com/pub/player/platy3',
#   'url': 'https://www.chess.com/member/platy3',
#   'name': 'Alan Pichot',
#   'username': 'platy3',
#   'title': 'GM',
#   'followers': 1224,
#   'country': 'https://api.chess.com/pub/country/AR',
#   'location': 'Buenos Aires',
#   'last_online': 1616240912,
#   'joined': 1433174480,
#   'status': 'premium',
#   'is_streamer': False},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/11519726.b0b9d520.200x200o.a3c33d802067.jpeg',
#   'player_id': 11519726,
#   '@id': 'https://api.chess.com/pub/player/playingsomechess',
#   'url': 'https://www.chess.com/member/Playingsomechess',
#   'name': 'Enrico Sevillano',
#   'username': 'playingsomechess',
#   'title': 'GM',
#   'followers': 0,
#   'country': 'https://api.chess.com/pub/country/US',
#   'last_online': 1542393544,
#   'joined': 1365953981,
#   'status': 'premium',
#   'is_streamer': False},
#  ...]

# %%
conn = MongoClient('localhost', 27017)

# %%
db = conn.chessdb
type(db)
# Out:
# pymongo.database.Database

# %%
collection = db.info_jogadores
type(collection)
# Out:
# pymongo.collection.Collection

# %%
collection.insert_many(json_chess['user'])
