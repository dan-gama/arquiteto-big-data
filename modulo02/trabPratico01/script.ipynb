# %% [markdown]
# # Abre o arquivo de configuração

# %%
import json

with open('appsettings.json', encoding='utf-8') as json_file:
    appSettings = json.load(json_file)

# %%
# Testa o arquivo de configuração
print(appSettings['MySQL']['Schema'])
# Out:
# TrabModulo02

# %% [markdown]
# # Coletando as informações dos arquivos

# %%
import pandas as pd
import os

# %%
df_list = []

# Caminho dos arquivos .csv
pathFiles = os.getcwd() + '\\data'

for file in os.listdir(pathFiles):
    filePath = os.path.join(pathFiles, file)
    df = pd.read_csv(filePath, sep='|', encoding='latin-1')
    df_list.append(df)
    #print(filePath)

df = pd.concat(df_list)
df.reset_index(drop=True, inplace=True)
df[:20]
# Out:
#     cod_pessoa data_coleta     genero data_nascimento animal_estimacao  \
# 0     10141743  2020-01-01  Masculino      1981-04-25            peixe
# 1     10141860  2020-01-01   Feminino      1966-01-19            peixe
# 2     10142548  2020-01-01  Masculino      1973-08-02        tartaruga
# 3     10142591  2020-01-01  Masculino      1997-03-05             gato
# 4     10142654  2020-01-01   Feminino      1969-08-05        tartaruga
# 5     10141523  2020-01-02   Feminino      1998-09-24             gato
# 6     10141996  2020-01-02   Feminino      1973-03-13        tartaruga
# 7     10142089  2020-01-02   Feminino      1970-03-23             gato
# 8     10142145  2020-01-02  Masculino      1998-08-01            peixe
# 9     10142520  2020-01-02  Masculino      1994-05-09            peixe
# 10    10143160  2020-01-02   Feminino      1967-09-18        tartaruga
# 11    10141712  2020-01-03  Masculino      1951-08-13            peixe
# ...

# %%
df.count()
# Out:
# cod_pessoa          2127
# data_coleta         2127
# genero              2127
# data_nascimento     2127
# animal_estimacao    2127
# clima               2127
# bebida_favorita     2127
# hobbies             2127
# dtype: int64

# %%
# Biblioteca que consegue inserir todo o Dataframe no banco de dados
from sqlalchemy import create_engine

engine = create_engine(appSettings['MySQL']['SQLAlchemy'], echo=False)
df.to_sql(name=appSettings['MySQL']['LoadTable'], con=engine, if_exists="replace", index=False)
# Out:
# 2127
